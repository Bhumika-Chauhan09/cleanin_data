# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhumika-Chauhan09/cleanin_data/blob/main/visual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt  # Import the matplotlib.pyplot module



df = pd.read_csv('ExerciseData.csv')

# Display the first few rows of the DataFrame
#df.head()
df['distance']=pd.to_numeric(df['distance'],errors='coerce')
df['speed']=pd.to_numeric(df['speed'],errors='coerce')

df['distance'].fillna(method='ffill',inplace=True)
df['speed'].fillna(method='ffill',inplace=True)
plt.xlabel('distance')
plt.ylabel('speed')

plt.tight_layout()
plt.show()

#compute stats
mean_distance=df['distance'].mean()
median_speed=df['speed'].median()
std_dev_distance=df['speed'].std()
print (f"Mean distance:{mean_distance}")
print(f"Median speed:{median_speed}")
print(f"standard deviation of distance:{std_dev_distance}")



# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(df['distance'], df['speed'], alpha=0.5)
plt.xlabel('distance')
plt.ylabel('speed')
plt.title('Scatter Plot of Distance vs. speed')
plt.show()
# Out:
# <ipython-input-15-915081913e2b>:6: DtypeWarning: Columns (7,9,10,11,13,14,15,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ExerciseData.csv')
# Mean distance:28.802264246880018
# Median speed:25.92
# standard deviation of distance:10.586459268703502
